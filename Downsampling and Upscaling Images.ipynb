# %% [markdown]
# ##Subject: Signal and Image Processing
# ###Topic: Downsampling and Upscaling

# %% [markdown]
# ## Aim: Spatial resolution and grey level resolution
#
# a. Apply grayscale resolution on the test image to obtain new image.
#
# 1. Calculate the compression ratio between the test image and new image
# 2. Comment on subjective quality of the image for various levels of grayscale resolution
#
# b. Apply sampling resolution on the test image to obtain the new image.
#
#
# 1. Calculate the compression ratio between the test image and new image
# 2. Comment on subjective quality of the image for various down sampling rates

# %%
# Import cv2, matplotlib, numpy
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
#Read the image
image = cv2.imread("/content/cameraman.tif",0)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FA3F086E670>

# %%
plt.imshow(image,cmap = "gray")
#show image

# %%
image.shape
#obtain image shape
# Out:
# (512, 512)

# %%
image.size
#obtain image size
# Out:
# 262144

# %%
#Know the type of the image
type(image)
# Out:
# numpy.ndarray

# %%
image
# Out:
# array([[156, 157, 160, ..., 152, 152, 152],
#        [156, 157, 159, ..., 152, 152, 152],
#        [158, 157, 156, ..., 152, 152, 152],
#        ...,
#        [121, 123, 126, ..., 121, 113, 111],
#        [121, 123, 126, ..., 121, 113, 111],
#        [121, 123, 126, ..., 121, 113, 111]], dtype=uint8)

# %%
new_image = image[::2,::2]
cv2_imshow(new_image)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FA3E1B54760>

# %%
new_image.size
# Out:
# 65536

# %%
new_image.shape
# Out:
# (256, 256)

# %%
img=new_image[::2,::2]
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=128x128 at 0x7FA3E1B5A1F0>

# %% [markdown]
# ##Upsampling techniques:
# - nearest neighbour
# - bilinear interpolation
# - cubic

# %%
#Ask for the number of bit in which a pixel has to be represented in the new image
[m,n]=image.shape
print(m,n)
b = int(input("Enter the bit size of new image"))
def change_bit_size(b,image):
  image3= np.zeros((m,n), dtype= np.int) #creating new image matrix

  for i in range(m):
    for j in range(n):
      image3[i,j] = (2**b - 1)/255*image[i,j]
  plt.imshow(image3, cmap='gray')
change_bit_size(b,image)
# Out:
# 512 512
# Enter the bit size of new image2
# <ipython-input-17-553cd3b11158>:6: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   image3= np.zeros((m,n), dtype= np.int) #creating new image matrix

# %% [markdown]
# ##Conclusion
# In this lab experiment we used python modules such as numpy, matplotlib.pyplot, cv2, and the fumction cv2_imshow to upscale and downscale images. This can be done by sampling and there exist various techniques to do so. In the down-sampling technique, the number of pixels in the given image is reduced depending on the sampling frequency. Due to this, the resolution and size of the image decrease. The number of pixels in the down-sampled image can be increased by using up-sampling interpolation techniques. The up-sampling technique increases the resolution as well as the size of the image.
#
# Some commonly used up-sampling techniques are
#   *   Nearest neighbor interpolation
#   *   Bilinear interpolation
#   *   Cubic interpolation
